# %% [markdown]
# # Natural Language Processing
#
#
# ## Defining Natural Language Processing
#
# As we continue further into our content this semester, you have probably noticed that each tool takes us to a new level of being able to conduct analysis with less code. As we progress, we move toward what are called "higher level" programming tools. Python itself is a high-level programming language, meaning that it is written in a way that is easier for humans to read than computers, with lots of translation happening behind the scenes.
#
# Tools like `pandas` remove a lot of the manual work from data processing. `numpy` and `scipy` handle much of the mathematical and statistical work that we want to do with our data. Natural Language Processing (NLP) is a tool similar to regex, but allowing us to take our text analytics to entirely new levels.
#
# Where regex allows us to look for text-based patterns in our words or string content, we want to go further. We want to look for **meaning**-based content. How do I find content that reflects anger? What words are most common in those contexts? What about when the content reflects joy? Sadness? Regex is not enough in these cases, and so we build to an even more powerful tool.
#
# NLP is a broad set of tools designed in order to enable users to work with text in ways that a human might work with text. When we work with text, we look for structures like sentences, and within those sentences we look for nouns to tell us who or what is the focus of the content. We look for verbs to understand what is happening. Adjectives and other descriptors help us to better understand the nuances of context. NLP models are trained to recognize these elements in text, and to be able to leverage that content to break text down and provide human users valuable information at a larger scale than would be possible if the document were simply read (slowly) by a human.
#
# | Regex | NLP |
# | --- | --- |
# | Create patterns to match in text | Identify the structure of text and use that to refine information|
# | Used to verify or find data | Used to analyze data |
# | Applies user-defined rules | Relies heavily on ML-based (or other) models |
#
#
# ## What NLP can do
#
# So what can NLP do for us?
#
# ### Identify parts of speech
#
# When we pass a document (really a string, but typically we provide a fairly large string to an NLP algorithm) to an NLP model, it is able to identify parts of speech (nouns, verbs, etc.). This enables us to quickly break down our text to find various kinds of keywords, and is the first step in many more complex pipelines.
#
# ### Iterate over sentences
#
# NLP can identify sentences within a document. This makes for a powerful iterative tool, as we will be able to define a processing pipeline for each sentence, and then apply that pipeline to as many sentences as exist within our document, without having to write complex code to try and recognize where each sentence starts and ends (this is MUCH harder than it sounds).
#
# ### Find words used to describe various nouns (or anything else!)
#
# Beyond simply identifying parts of speech, NLP models can be used to build a structural dependency tree of each sentence. This structure allows us to associate adjectives with their respective nouns, or adverbs to the verb that they modify. We can explore how various entities are described in our document based on word associations. We can even visualize the structure of the sentence using simple mapping functions.
#
# ### Filter text for analysis
#
# We can use NLP to filter our text. We can look for sentences about a specific entity, or explore other ways of filtering our text in order to create a better understanding of overall patterns in the document.
#
# ### Conduct sentiment analysis
#
# One of the most powerful capabilities resulting from NLP models is the ability to analyze sentiment within the text. Words have the ability to convey literal meanings, as well as the more subtle capacity to convey emotion. By looking for word combinations in our text, NLP models can provide sentiment measurements at the word, sentence, or document level. This provides the ability to sort through texts for specific sentiments to learn about the way in which emotion affects the outcomes we are examining in text. One example might be looking through descriptions for negative emotions, and being able to respond to unhappy customers by flagging negative descriptions.
#
#
# ## Implementing NLP models
#
# To get started with NLP models, we need to install the right libraries (and a corpus!). The library that we will use is `spacy`, although there are multiple other options available to us. One other common NLP library is `nltk`, the Natural Language Toolkit (NLTK). In my experience NLTK is more commonly employed when someone wants to create their own model from scratch, rather than implement pre-built and optimized NLP models.
#
# In addition to a library to conduct NLP, we also rely on a **corpus**. A corpus is essentially a model of a specific language that is built to enable the actual analysis. `spacy` as a library is a general structure that can be implemented on ANY language. The corpus allows us to select a specific language, and a model of that language built on a specific set of information.
#
# When we install `spacy`, we will also download the `en_core_web_sm` corpus. This corpus is a small-sized model of the english language, and was trained on web-based data. That means that it will perform best on data drawn from websites, and is not as strong a model for other contexts (like analyzing Pride and Prejudice). That doesn't mean that we can't use in other contexts, but it does suggest that results will not be as refined or accurate.

# %% [markdown]
# We need to get ourselves some text to analyze before we jump into the NLP world. In true form, here is another favorite old book. We will take a look at the first three chapters of Jane Eyre from [Project Gutenberg](https://www.gutenberg.org/browse/scores/top).

# %%
import requests

jane = requests.get(
"https://github.com/dustywhite7/Econ8320/raw/master/AssignmentData/janeEyreCh1to3.txt"
).text

# %% [markdown]
# You can take a look at the text to get an idea of what we will be working with. Once you're ready, we will go ahead and import the `spacy` library. The very first thing we do once we import `spacy` is to load the coprus, so that we are able to use its language models to parse our document. Let's run the code, and then discuss what is happening.

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp(jane)

# %% [markdown]
# ### The structure of a parsed document
#
# When we create an `nlp` object based on our corpus, we are creating our pipeline for working with text. Our corpus contains all of the information necessary to prepare our data for analysis. When we create our `doc` object, we are passing our document through the processing pipeline. Our new parsed document (`doc` in this case), has some important **attributes**:
#
# - `sents` - a generator function to iterate over each sentence in the document
# - `token` - each individual element of the document
#     - Elements exist at the word/punctuation level
#
# After being processed, our document has been broken down into tokens, and then (to some extent) reconstructed into sentences. Additionally, each token is mapped out in relation to the other tokens within a sentence, and is described using various attributes to inform how that token relates to the text around it.

# %%
test = [i.text.replace('\n', ' ') for i in doc.sents][:10]
# print first 10 sentences, replacing newlines with spaces

test
# Out:
# ['CHAPTER I   There was no possibility of taking a walk that day.',
#  'We had been wandering, indeed, in the leafless shrubbery an hour in the morning; but since dinner (Mrs. Reed, when there was no company, dined early) the cold winter wind had brought with it clouds so sombre, and a rain so penetrating, that further outdoor exercise was now out of the question.  ',
#  'I was glad of it: I never liked long walks, especially on chilly afternoons: dreadful to me was the coming home in the raw twilight, with nipped fingers and toes, and a heart saddened by the chidings of Bessie, the nurse, and humbled by the consciousness of my physical inferiority to Eliza, John, and Georgiana Reed.  ',
#  'The said Eliza, John, and Georgiana were now clustered round their mama in the drawing-room: she lay reclined on a sofa by the fireside, and with her darlings about her (for the time neither quarrelling nor crying) looked perfectly happy.',
#  'Me, she had dispensed from joining the group; saying, “She regretted to be under the necessity of keeping me at a distance; but that until she heard from Bessie, and could discover by her own observation, that I was endeavouring in good earnest to acquire a more sociable and childlike disposition, a more attractive and sprightly manner—something lighter, franker, more natural, as it were—she really must exclude me from privileges intended only for contented, happy, little children.”  “What does Bessie say I have done?”',
#  'I asked.  “Jane, I don’t like cavillers or questioners; besides, there is something truly forbidding in a child taking up her elders in that manner.',
#  'Be seated somewhere; and until you can speak pleasantly, remain silent.”  ',
#  'A breakfast-room adjoined the drawing-room, I slipped in there.',
#  'It contained a bookcase: I soon possessed myself of a volume, taking care that it should be one stored with pictures.',
#  'I mounted into the window-seat: gathering up my feet, I sat cross-legged, like a Turk; and, having drawn the red moreen curtain nearly close, I was shrined in double retirement.  ']

# %% [markdown]
# ### Understanding tokens
#
# Recall that each word is represented as a token in the processed document. These tokens are immensely powerful. They are the word, but also more than that. Words in the English language are often modified based on context. Verbs are conjugated, nouns may be plural, among many possibilities. Each word is **tokenized** through our corpus in order to identify the underlying word.
#
# This is important, because we might want to look for each instance of a single word in our corpus. Let's say that we want to find every instance of "eat". If we look for "eat", we want to make sure that "eats" and "ate", as well as "eating" and other forms are all considered. This is where tokenization becomes critical. Each token contains the text value from the original document, but also the **lemmatized** word. The lemma is the base form of the word, allowing us to search for lemmas rather than the text word. This streamlines our ability to analyze text by focusing on lemmas rather than unprocessed text.
#
# Other valuable attributes are also associated with our tokens:
# - `lemma_` - the "root word" from which a token/word is derived
# - `pos_` - the part of speech of a token/word
# - `dep_` - the relationship of dependent tokens to the parent token (adjectives to nouns, etc.)
# - `like_email`/`like_num`/`like_url` - check if a token is like an email, number, or url (unlikely in Jane Eyre)
#
# Let's look at the first 100 non-space, non-punctuation lemmas in Jane Eyre:

# %%
lemmas100 = [(i.lemma_, i.text) for i in doc if (not i.is_punct) and (not i.is_space)][:100]

print(lemmas100) # The lemma comes first, followed by the actual word in the text.
# Out:
# [('chapter', 'CHAPTER'), ('I', 'I'), ('there', 'There'), ('be', 'was'), ('no', 'no'), ('possibility', 'possibility'), ('of', 'of'), ('take', 'taking'), ('a', 'a'), ('walk', 'walk'), ('that', 'that'), ('day', 'day'), ('we', 'We'), ('have', 'had'), ('be', 'been'), ('wandering', 'wandering'), ('indeed', 'indeed'), ('in', 'in'), ('the', 'the'), ('leafless', 'leafless'), ('shrubbery', 'shrubbery'), ('an', 'an'), ('hour', 'hour'), ('in', 'in'), ('the', 'the'), ('morning', 'morning'), ('but', 'but'), ('since', 'since'), ('dinner', 'dinner'), ('Mrs.', 'Mrs.'), ('Reed', 'Reed'), ('when', 'when'), ('there', 'there'), ('be', 'was'), ('no', 'no'), ('company', 'company'), ('dine', 'dined'), ('early', 'early'), ('the', 'the'), ('cold', 'cold'), ('winter', 'winter'), ('wind', 'wind'), ('have', 'had'), ('bring', 'brought'), ('with', 'with'), ('it', 'it'), ('cloud', 'clouds'), ('so', 'so'), ('sombre', 'sombre'), ('and', 'and'), ('a', 'a'), ('rain', 'rain'), ('so', 'so'), ('penetrate', 'penetrating'), ('that', 'that'), ('further', 'further'), ('outdoor', 'outdoor'), ('exercise', 'exercise'), ('be', 'was'), ('now', 'now'), ('out', 'out'), ('of', 'of'), ('the', 'the'), ('question', 'question'), ('I', 'I'), ('be', 'was'), ('glad', 'glad'), ('of', 'of'), ('it', 'it'), ('I', 'I'), ('never', 'never'), ('like', 'liked'), ('long', 'long'), ('walk', 'walks'), ('especially', 'especially'), ('on', 'on'), ('chilly', 'chilly'), ('afternoon', 'afternoons'), ('dreadful', 'dreadful'), ('to', 'to'), ('I', 'me'), ('be', 'was'), ('the', 'the'), ('come', 'coming'), ('home', 'home'), ('in', 'in'), ('the', 'the'), ('raw', 'raw'), ('twilight', 'twilight'), ('with', 'with'), ('nip', 'nipped'), ('finger', 'fingers'), ('and', 'and'), ('toe', 'toes'), ('and', 'and'), ('a', 'a'), ('heart', 'heart'), ('sadden', 'saddened'), ('by', 'by'), ('the', 'the')]

# %% [markdown]
# We can also filter words by part of speech using the `pos_` attribute of our tokens. Let's look for the first 100 nouns in the text.

# %%
nouns = [i.text for i in doc if i.pos_=='NOUN'][:100]

print(nouns) # The lemma comes first, followed by the actual word in the text.
# Out:
# ['CHAPTER', 'possibility', 'walk', 'day', 'leafless', 'shrubbery', 'hour', 'morning', 'dinner', 'company', 'winter', 'wind', 'clouds', 'rain', 'exercise', 'question', 'walks', 'afternoons', 'home', 'twilight', 'fingers', 'toes', 'heart', 'chidings', 'nurse', 'consciousness', 'inferiority', 'mama', 'drawing', 'room', 'sofa', 'fireside', 'darlings', 'time', 'crying', 'group', 'necessity', 'distance', 'observation', 'earnest', 'disposition', 'manner', 'franker', 'privileges', 'children', 'cavillers', 'questioners', 'child', 'elders', 'manner', 'breakfast', 'room', 'drawing', 'room', 'bookcase', 'volume', 'care', 'pictures', 'window', 'seat', 'feet', 'moreen', 'curtain', 'retirement', 'Folds', 'drapery', 'view', 'hand', 'left', 'panes', 'glass', 'day', 'intervals', 'leaves', 'book', 'aspect', 'winter', 'afternoon', 'blank', 'mist', 'cloud', 'scene', 'lawn', 'storm', 'shrub', 'rain', 'blast', 'book', 'History', 'letterpress', 'pages', 'child', 'blank', 'haunts', 'sea', 'fowl', 'rocks', 'promontories', 'coast', 'isles']

# %% [markdown]
# Pretty cool! If you look through that list, you'll see that there are a lot of different kinds of nouns. Two that stood out to me are "drawing" and "room"... oh wait... that's ONE NOUN that is two words! And leads us right into **noun chunks**. ;)
#
# Sometimes, you want to be able to see a "complete" noun, and noun chunks are the tool to use!

# %%
nouns = [i.text.replace('\n', ' ') for i in doc.noun_chunks][:100] # getting rid of new lines in our noun chunks

print(nouns)
# Out:
# ['I', 'no possibility', 'a walk', 'We', 'the leafless shrubbery', 'the morning', 'dinner', 'Mrs. Reed', 'no company', 'the cold winter wind', 'it', 'clouds', 'further outdoor exercise', 'the question', 'I', 'it', 'I', 'long walks', 'chilly afternoons', 'me', 'the coming home', 'the raw twilight', 'nipped fingers', 'toes', 'a heart', 'the chidings', 'Bessie', 'the nurse', 'the consciousness', 'my physical inferiority', 'Eliza', 'John', 'Georgiana Reed', 'The', 'Eliza', 'John', 'Georgiana', 'their mama', 'the drawing-room', 'she', 'a sofa', 'the fireside', 'her darlings', 'her', 'the time', 'crying', 'Me', 'she', 'the group', 'She', 'the necessity', 'me', 'a distance', 'she', 'Bessie', 'her own observation', 'I', 'good earnest', 'a more sociable and childlike disposition', 'something', 'franker', 'it', 'she', 'me', 'privileges', 'contented, happy, little children', 'Bessie', 'I', 'I', 'Jane', 'I', 'cavillers', 'questioners', 'something', 'a child', 'her elders', 'that manner', 'you', 'A breakfast-room', 'the drawing-room', 'I', 'It', 'a bookcase', 'I', 'myself', 'a volume', 'care', 'it', 'pictures', 'I', 'the window-seat', 'my feet', 'I', 'a Turk', 'the red moreen curtain', 'I', 'double retirement', 'Folds', 'scarlet drapery', 'my view']

# %% [markdown]
# That's better. Noun chunks include all of the modifiers for a given noun, and make it easier to build a more complete understanding of the references being made. Why do we care? Because "the red moreen curtain" is the object, and we want to be sure to understand the implication of the full object, rather than only the word within the noun chunk that is actually a noun.
#
# If we want to understand more about the nature of the relationships between words within a sentence, we can plot a dependency tree.
#
# **NOTE: When you run the following code, be sure to click the STOP button when you're done, or no other code will run! The renderer for the dependency tree will keep running until you terminate it!**

# %%
from spacy import displacy

sent = [i for i in doc.sents][100]
displacy.serve(sent, style="dep")
# Out:
# /home/codio/miniconda3/lib/python3.9/site-packages/spacy/displacy/__init__.py:103: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="54db8ba4774144ba9d4fa35023432702-0" class="displacy" width="7925" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Bessie</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">answered</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">not;</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">but</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">ere</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">long,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">addressing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">me,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">said—</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">
#
# “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">You</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">ought</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">be</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">aware,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">Miss,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">you</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">under</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">obligations</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">Mrs.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Reed:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">she</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">keeps</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">you:</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="curre
# Using the 'dep' visualizer
# Serving on http://0.0.0.0:5000 ...
#
# Shutting down server on port 5000.

# %% [markdown]
# Using this mapping, we can see each of the clauses of the sentence, and how words within the sentence relate to one another. The mapping can help us to understand whether or not we have correctly identified parts of speech that are associated with the topics we are trying to uncover in our code.
#
#
# ## Sentiment Analysis
#
# My personal favorite part of NLP, sentiment analysis is a very powerful instrument for understanding text and creating actionable items. Many firms use sentiment analysis in combination with their social media accounts to measure engagement and understand how successful marketing campaigns or other interactions are with target audiences.
#
# In order to conduct sentiment analysis using spacy, we are going to use a library called `spacytextblob`. This library includes supplemental material that expands the english corpus' ability to process our data. When utilized, `spacytextblob` is going to add sentiment analysis models to the general pipeline created through `spacy`.
#
# We can incorporate the `SpacyTextBlob` process into our pipeline like this:

# %%
import spacy
from spacytextblob.spacytextblob import SpacyTextBlob
import requests

jane = requests.get(
"https://github.com/dustywhite7/Econ8320/raw/master/AssignmentData/janeEyreCh1to3.txt"
).text

nlp = spacy.load('en_core_web_sm')
nlp.add_pipe('spacytextblob')

blob = nlp(jane)

sents = [i for i in blob.sents]

for sentence in sents[:10]:
    print("Polarity: {0:3.2f}, Subjectivity: {1:3.2f}".format(sentence._.polarity, sentence._.subjectivity))
# Out:
# Polarity: 0.00, Subjectivity: 0.00
# Polarity: -0.17, Subjectivity: 0.60
# Polarity: -0.30, Subjectivity: 0.69
# Polarity: 0.13, Subjectivity: 0.67
# Polarity: 0.41, Subjectivity: 0.66
# Polarity: 0.00, Subjectivity: 0.00
# Polarity: 0.37, Subjectivity: 0.53
# Polarity: 0.00, Subjectivity: 0.00
# Polarity: 0.00, Subjectivity: 0.00
# Polarity: 0.03, Subjectivity: 0.13

# %% [markdown]
# We can add code to our processing pipeline using the `nlp.add_pipe()` method on our `nlp` object. In this case, we are adding the sentiment analysis information created through `SpacyTextBlob`, but this can be literally anything. We can create any kind of function that we want to implement on our code, and can add that functionality to our pipeline in the same way. More examples are available in the `spacy` [documentation](https://spacy.io/usage/processing-pipelines#pipelines).
#
# If you want to get more in-depth with NLP, I highly recommend that you explore the course material available through `spacy`'s own NLP curriculum (freely available!): https://course.spacy.io/en/

# %% [markdown]
# ## Solve it!
#
# In this project, you will use the text from chapters 44 and 45 of *Pride and Prejudice*. Please find the following information:
#
# - The number of sentences (store as `int` in a variable named `sentences`)
# - A list of all proper nouns used across the two chapters (stored as strings in the `names` variable)
# - A DataFrame containing a count of the top 20 adjectives used in the text (stored in the `adjectives` variable)
#     - Be sure to make all words lower case ONLY!
# - A bar chart of the top 20 adjectives used in the text stored in a variable called `fig`
#
#
# Place all of your code in the cell below, labeled `#si-exercise`.

# %%
#si-exercise
import requests
import spacy
import plotly.express as px
import pandas as pd
from spacy import displacy
from spacytextblob.spacytextblob import SpacyTextBlob

nlp = spacy.load("en_core_web_sm")


pride = requests.get("https://github.com/dustywhite7/pythonMikkeli/blob/master/exampleData/prideAndPrejudiceChapters.txt").text
doc = nlp(pride)



# Number of sentences
sentences = len(list(doc.sents))
print(sentences)

#proper nouns
names = [i for i in doc if (i.pos_ =="PROPN")]
print(names)

#top 20 adjectives used in the text
s = pd.Series([i.text for i in names]).value_counts()[:20]
print(s)

adjectives = pd.DataFrame(s).reset_index()
adjectives.columns = ['Name', 'Frequency']
adjectives.set_index('Name')
adjectives['Name']=adjectives['Name'].str.lower()
print(adjectives)
# Out:
# 906
# [DOCTYPE, html, head, meta, charset="utf-8, rel="dns, prefetch, rel="dns, prefetch, rel="dns, prefetch, href="https://github, cloud.s3.amazonaws.com, rel="dns, prefetch, href="https://github.githubassets.com, crossorigin, dark-1ee85695b584.css, dark_dimmed-8c42799cfb52.css, dark_high_contrast, dc99d916bf90.css, dark_colorblind-0a83868d0e43.css, light_colorblind-3c798f5a8bef.css, light_high_contrast-4c72a7f3b765.css, theme="light_tritanopia, light_tritanopia-222bf22536c7.css, theme="dark_tritanopia, c1d9496197fa.css, primitives-0b5bee5c70e9.css, primer-44fa1513ddd0.css, global-1c8bb26336c1.css, github-07f750db5d7c.css, fa69f138fe8d.css, type="application, json, fd67db66fb1c.js"></script, vendors, node_modules_smoothscroll, polyfill_dist_smoothscroll_js, node_modules_stacktrace, observer_dist_index_esm_js-9f960d9b217c.js"></script, node_modules_primer_behaviors_dist_esm_focus, vendors, node_modules_github_combobox, element_dist_index_js-8a621df59e80.js"></script, vendors, events_dist_index_js, node_modules_stacktrace, parser_dist_stack-443cd5, node_modules_github_remote, co-27181b-3509ed8075c4.js"></script, app_assets_modules_github_onfocus_ts, ui_packages-6fe316, github, elements-34cbf079a4f4.js"></script, node_modules_github_catalyst_lib_index_js, node_modules_braintree_browser, 6fc33e963fc0.js"></script, form_dist_index_js, node_modules_delegated, events_dist_inde-893f9f, vendors, node_modules_scroll, anchoring_dist_scroll, vendors, node_modules_color, vendors, node_modules_primer_behaviors_dist_esm_dimensions_js, node_modules_github_jtml_lib_index_js-95b84ee6bc34.js"></script, eff4af278797.js"></script, ui_packages_hydro, analytics_hydro, analytics_ts-82813f-05346aa543fe.js"></script, app_assets_modules_github_behaviors_task, list_ts, app_assets_modules_github_onfocus_ts, app_assets_modules_github_behaviors_ht-83c235, 9285faa0e011.js"></script, vendors, events_dist_index_js, node_modules_github_catalyst_lib_index_js-06ff531, f6b365a47eda.js"></script, lib-1fbfc5be2c18.js"></script, >, react_dist_index_esm_js, node_modules_primer_react_lib, node_modules_primer_react_lib, esm_Box_Box_js-8f8c5e2a2cbf.js"></script, node_modules_primer_react_lib, react_dist_index_esm_mjs, cb996b1b8e38.js"></script, vendors, node_modules_primer_react_lib, esm_TooltipV2_Tooltip_js, a1d2cb4ed6ce.js"></script, node_modules_primer_react_lib, esm_ActionList_index_js, e55780ce0aba.js"></script, vendors, node_modules_primer_react_lib, esm_Text_Text_js, node_modules_primer_react_lib, vendors, node_modules_primer_react_lib, esm_FormControl_FormControl_js-2a0ace3735a5.js"></script, node_modules_primer_react_lib, esm_AnchoredOverlay_AnchoredOverlay_js-61314bd0d65c.js"></script, dom_dist_index_js-3b41341d50fe.js"></script, node_modules_primer_react_lib, esm_Heading_Heading_js, node_modules_primer_react_lib, node_modules_primer_react_lib, esm_ConfirmationDialog_ConfirmationDialog_js-98120b3f8583.js"></script, vendors, node_modules_primer_react_lib, esm_Label_Label_js, node_modules_primer_react_lib, eb91f98e501d.js"></script, vendors, node_modules_primer_react_lib, esm_Dialog_js, node_modules_primer_react_lib, vendors, node_modules_primer_react_lib, esm_AvatarStack_AvatarStack_js, node_modules_primer_react_lib, esm_Bre, app_ts-86733e888f0e.js"></script, ui_packages_paths_index_ts, ad6a9a567cec.js"></script, ui_packages_commit, attribution_index_ts, ui_packages_commit, status_index_ts, ui_packages, bb2049, app_assets_-e50ab6, fd8396d2490b.js"></script, view-0204a0aa15e2.js"></script, pythonMikkeli, master, dustywhite7, pythonMikkeli, content="/:user_id/:repository, name="route, name="route, name="request, content="874C:6D4BD:364334:47B2BE:662325C4, content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiI4NzRDOjZENEJEOjM2NDMzNDo0N0IyQkU6NjYyMzI1QzQiLCJ2aXNpdG9yX2lkIjoiNzA1NzI5OTc1MDYzNjQzMDc4OCIsInJlZ2lvbl9lZGdlIjoiaWFkIiwicmVnaW9uX3JlbmRlciI6ImlhZCJ9, hmac, name="github, value="repo_source, link, content="c1kuD, K2HIVF635lypcsWPoD4kilo5, jA_wBFyT4uMY, content="GXs5KoUUk ...
# aria                             124
# version="1.1                      90
# viewBox="0                        90
# svg                               89
# width="16                         79
# pythonMikkeli                     53
# div                               45
# octicon                           41
# /template                         37
# Darcy                             31
# 0                                 29
# li                                28
# dustywhite7                       24
# d                                 23
# Miss                              23
# Elizabeth                         21
# node_modules_primer_react_lib     20
# Mr.                               19
# d="M8                             17
# type="button                      16
# Name: count, dtype: int64
#                              Name  Frequency
# 0                            aria        124
# 1                    version="1.1         90
# 2                      viewbox="0         90
# 3                             svg         89
# 4                       width="16         79
# 5                   pythonmikkeli         53
# 6                             div         45
# 7                         octicon         41
# 8                       /template         37
# 9                           darcy         31
# 10                              0         29
# 11                             li         28
# 12                    dustywhite7         24
# 13                              d         23
# 14                           miss         23
# 15                      elizabeth         21
# 16  node_modules_primer_react_lib         20
# 17                            mr.         19
# 18                          d="m8         17
# 19                   type="button         16

# %%
sentences
# Out:
# 904

# %%
names
# Out:
# [a11y,
#  <link rel="dns-prefetch,
#  ">
#    <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">
#    <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com,
#  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">
#    <link,
#  " href="https://github.githubassets.com" crossorigin>
#    <link,
#  crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-f13f84a2af0d.css,
#  dark_dimmed-8c42799cfb52.css,
#  data-color-theme="dark_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/dark_high_contrast-dc99d916bf90.css,
#  data-color-theme="light_colorblind" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_colorblind-3c798f5a8bef.css,
#  data-color-theme="light_high_contrast" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_high_contrast-4c72a7f3b765.css,
#  data-color-theme="light_tritanopia" crossorigin="anonymous" media="all" rel="stylesheet" data-href="https://github.githubassets.com/assets/light_tritanopia-222bf22536c7.css,
#  >
#      <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/primer-primitives-0b5bee5c70e9.css,
#  github-07f750db5d7c.css,
#  json,
#  wp,
#  runtime-1bf7ee9c7d01.js"></script,
#  " defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors,
#  node_modules_smoothscroll,
#  node_modules_stacktrace,
#  defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/vendors-node_modules_github_combobox-nav_dist_index_js-node_modules_github_markdown-toolbar-e-820fc0,
#  -ui_packages-6fe316,
#  node_modules_github_catalyst_lib_index_js,
#  node_modules_stacktrace,
#  esm_js,
#  esm_js,
#  node_modules_scroll,
#  node_modules_primer_behaviors_dist_esm_dimensions_js,
#  analytics_hydro,
#  analytics_ts-82813f,
#  -app_assets_modules_github_onfocus_ts-app_ass-421cec-9de4213015af.js"></script,
#  view_ts-94209c43e6af.js"></script,
#  app_assets_modules_github_behaviors_ajax-error_ts,
#  app_assets_modules_github_behaviors_include-2e2258-05fd80a7ea89.js"></script,
#  app_assets_modules_github_behaviors_commenting_edit_ts-app_assets_modules_github_behaviors_ht-83c235-9285faa0e011.js"></script,
#  global-6d6db5144cc3.js"></script,
#  app_assets_modules_github_repositories_get-repo-element_ts,
#  react_dist_index_esm_js,
#  -esm_ActionList_index_js,
#  -esm_Text_Text_js,
#  -esm_Text-7845da-3aa4d914d36c.js"></script,
#  -esm_FormControl_FormControl_js,
#  es-09461f-46d4f0de9a1d.js"></script,
#  ui_packages_react-core_create,
#  ui_packages_react-core_register,
#  app_ts,
#  ad6a9a567cec.js"></script,
#  c2bab3,
#  -view,
#  defer="defer" type="application/javascript" src="https://github.githubassets.com/assets/ui_packages_code-view,
#  -,
#  search_FileResultsList_tsx-8a4187713fb7.js"></script,
#  exampleData,
#  prideAndPrejudiceChapters.txt,
#  master,
#  pythonMikkeli,
#  name="route-pattern,
#  content="/:user_id/:repository/blob/*name(/*path,
#  data-turbo-transient,
#  meta name="route-controller" content="blob" data-turbo-transient,
#  name="route-action,
#  <meta name="current-catalog-service-hash,
#  :F746F1:661F2497" data-pjax-transient="true"/><meta name="html-safe-nonce" content="935be68147ca11a786468595f89b427e9538f1bc2d573beeb182bead374a736b" data-pjax-transient="true"/><meta name="visitor-payload" content="eyJyZWZlcnJlciI6IiIsInJlcXVlc3RfaWQiOiJCMzBBOjlCRUY6QjE1RDNGOkY3NDZGMTo2NjFGMjQ5NyIsInZpc2l0b3JfaWQiOiI4NTU2Mzg4NzczMTIyNzQ1NDk1IiwicmVnaW9uX2VkZ2UiOiJpYWQiLCJyZWdpb25fcmVuZGVyIjoiaWFkIn0=" data-pjax-transient="true"/><meta name="visitor-hmac" content="e5c61a6385f099f8563cbf28409464539947a6e059523fcf77d403560c4ee32b" data-pjax-transient="true"/,
#  meta name="hovercard-subject-tag,
#  " content="repository:253822401" data-turbo-transient,
#  source-code,
#  file-tree,
#  copilot,
#  meta name="selected-link" value="repo_source" data-turbo-transient,
#  link,
#  <meta name="google-site-verification" content="c1kuD-K2HIVF635lypcsWPoD4kilo5-jA_wBFyT4uMY,
#  content="KT5gs8h0wvaagLKAVWq8bbeNwnZZK1r1XQysX3xurLU,
#  ">
#    <meta name="google-site-verification" content="ZzhVyEFwb7w3e0-uOTltm8Jsck2F5StVihD0exw2fsA,
#  content="GXs5KoUUkNCoaAZn7wPN-t01Pywp9M3sEjnt_3_ZWPc,
#  -x98H0j5cPqHWwSMm6dNU4GmODRoqxLiDzdx9I,
#  <meta name="analytics-location" content="/&lt;user-name&gt;/&lt;repo-name&gt;/blob/show,
#  <meta name="user-login" content="">
#
#
#
#      <meta name="viewport" content="width=device-width">
#
#        <meta name="description" content="Data Science Course Materials,
#  Aalto University,
#  Mikkeli,
#  pythonMikkeli,
#  /exampleData,
#  prideAndPrejudiceChapters.txt,
#  master,
#  pythonMikkeli,
#  ">
#        <link,
#  name="apple-itunes-app,
#  exampleData,
#  /prideAndPrejudiceChapters.txt,
#  image,
#  src,
#  content="https://opengraph.githubassets.com/73e2ecbb2c49942f88883fe8f234ebccb0e49ddee4bd0a709bb342e00717f208,
#  dustywhite7,
#  pythonMikkeli,
#  site" content="@github,
#  name="twitter:card" content="summary_large_image,
#  exampleData,
#  master,
#  pythonMikkeli,
#  description" content="Data Science Course Materials,
#  Aalto University,
#  Mikkeli - dustywhite7,
#  pythonMikkeli,
#  meta property="og,
#  image,
#  dustywhite7,
#  property="og,
#  image,
#  " content="Data Science Course Materials,
#  Aalto University,
#  Mikkeli - dustywhite7,
#  pythonMikkeli,
#  property="og,
#  image,
#  width,
#  content="1200,
#  property="og,
#  image,
#  height" content="600,
#  property="og,
#  site_name,
#  property="og,
#  type,
#  property="og,
#  exampleData,
#  master,
#  pythonMikkeli,
#  property="og,
#  dustywhite7,
#  exampleData,
#  /prideAndPrejudiceChapters.txt,
#  description" content="Data Science Course Materials,
#  Aalto University,
#  Mikkeli - dustywhite7,
#  pythonMikkeli,
#  <meta name="hostname,
#  <meta name="expected-hostname,
#  equiv="x,
#  equiv="x,
#  equiv="x,
#  equiv="x,
#  <meta name="turbo-cache-control" content="no-preview" data-turbo-transient=,
#  dustywhite7,
#  <meta name="octolytics-dimension-user_id,
#  name="octolytics-dimension-repository_is_fork" content="false" /><meta name="octolytics-dimension-repository_network_root_id" content="253822401" /><meta name="octolytics-dimension-repository_network_root_nwo" content="dustywhite7/pythonMikkeli" />
#
#
#
#    <meta name="turbo-body-classes,
#  content="logged-out env-production page-responsive">
#
#
#    <meta name="browser-stats-url" content="https://api.github.com/_private/browser/stats,
#  <meta name="browser-errors-url" content="https://api.github.com/_private/browser/errors,
#  <link,
#  rel="mask,
#  -,
#  icon,
#  " type="image/png,
#  <meta name="color-scheme,
#  >
#
#
#    <link rel="manifest" href="/manifest.json" crossOrigin="use-credentials,
#  </head>
#
#    <body,
#  env-production page-responsive" style="word-wrap,
#  env-production,
#  break-word,
#  content,
#  emphasis,
#  focus,
#  content</a,
#  >
#        <span,
#  Progress,
#  span,
#  0%,
#  " data-view-component="true" class="Progress-item progress-pjax-loader-bar,
#  json" data-target="react-partial.embeddedData">{"props":{"docsUrl":"https://docs.github.com/get-started/accessibility/keyboard-shortcuts"}}</script>
#    <div data-target="react-partial.reactRoot"></div,
#  /react,
#  class="Header-old header-logged-out js-details-container Details,
#  lg,
#  none,
#  border-0,
#  left-0 width-full height-full js-details-target,
#  d-flex flex-column flex-lg-row flex-items-center p-responsive height-full position-relative z-1,
#  lg,
#  a class="mr-lg-3 color-fg-inherit flex-order-2" href="https://github.com/" aria-label="Homepage,
#  " data-ga-click="(Logged out) Header,
#  homepage,
#  icon,
#  16 16" version="1.1" width="32" data-view-component="true" class="octicon octicon-mark-github,
#  path,
#  3.65-.88,
#  1.92-.08,
#  1.13.16.45.68 1.31 2.69.94,
#  .67.01,
#  .21-.15.45-.55.38A7.995,
#  >
#        </a>
#
#        <div,
#  a href="/login?return_to=https%3A%2F%2Fgithub.com%2Fdustywhite7%2FpythonMikkeli%2Fblob%2Fmaster%2FexampleData%2FprideAndPrejudiceChapters.txt"
#            class="d-inline-block,
#  d,
#  lg,
#  none,
#  fg,
#  -inherit,
#  dustywhite7,
#  exampleData,
#  Sign,
#  </div>
#
#        <div class="flex-1 flex-order-2 text-right">
#          <button aria-label="Toggle navigation" aria-expanded="false" type="button" data-view-component="true" class="js-details-target Button--link,
#  fg-inherit,
#  p-1,
#  ">  <span class="Button-content,
#  >
#      <span class="Button-label"><div class="HeaderMenu-toggle-bar,
#  my-1"></div,
#  >
#              <div class="HeaderMenu-toggle-bar,
#  my-1"></div,
#  >
#              <div class="HeaderMenu-toggle-bar rounded my-1"></div></span,
#  </button>
#        </div>
#      </div>
#
#
#      <div class="HeaderMenu,
#  lg,
#  relative,
#  ">
#        <div class="header-menu-wrapper d-flex flex-column flex-self-end flex-lg-row flex-justify-between flex-auto p-3 p-lg-0,
#  rounded-lg-0 mt-3,
#  mt-lg-0">
#            <nav,
#  class="mt-0,
#  lg-0,
#  none,
#  ">
#                  <li class="HeaderMenu-item,
#  lg,
#  no-wrap,
#  js-details-target,
#  <svg opacity="0.5,
#  " height="16,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-chevron-down HeaderMenu-icon ml-1">
#      <path,
#  5.22a.749.749,
#  lg,
#  lg,
#  lg-0,
#  none,
#  secondary d-flex flex-items-center,
#  Actions&quot;,&quot;label&quot;:&quot;ref_cta,
#  }" href="/features/actions,
#  <svg aria-hidden="true" height="24" viewBox="0,
#  " version="1.1" width="24" data-view-component="true" class="octicon octicon-workflow,
#  0-.5-.5ZM14.5,
#  >
#        <div,
#  fg-default,
#  any workflow,
#  a class="HeaderMenu-dropdown-link,
#  secondary d-flex flex-items-center,
#  Packages&quot;,&quot;label&quot;:&quot;ref_cta,
#  Packages;&quot,
#  }" href="/features/packages,
#  <svg aria-hidden="true" height="24" viewBox="0,
#  " version="1.1" width="24" data-view-component="true" class="octicon octicon-package,
#  color,
#  ">
#      <path d="M12.876.64V.639l8.25,
#  0Zm.875,
#  <div,
#  fg,
#  default,
#  packages,
#  lh-condensed d,
#  -block no-underline position-relative py-2 Link,
#  secondary d-flex flex-items-center,
#  Security&quot;,&quot;label&quot;:&quot;ref_cta,
#  Security;&quot,
#  " version="1.1" width="24" data-view-component="true" class="octicon octicon-shield-check,
#  color,
#  ">
#      <path d="M16.53 9.78a.75.75 0 0 0-1.06-1.06L11 13.19l-1.97,
#  1.06 0l5-5Z"></path><path d="m12.54.637,
#  22 4.976V10c0,
#  0-.173.237V10c0,
#  .14 0C17.22,
#  20.5 10V4.976a.25.25,
#  0-.173-.237l-8.25,
#  0-.154 0Z"></path,
#  fg,
#  -default,
#  vulnerabilities,
#  secondary d-flex flex-items-center,
#  Codespaces&quot;,&quot;label&quot;:&quot;ref_cta,
#  Codespaces;&quot,
#  }" href="/features/codespaces,
#  <svg aria-hidden="true" height="24" viewBox="0,
#  color,
#  ">
#      <path d="M3.5,
#  1.75.784,
#  1-1.75 1.75H3.25a1.75,
#  1-1.75-1.75ZM5.25 3.5a.25.25,
#  .138.112.25.25.25h13.5a.25.25,
#  .25-.25v-7.5a.25.25,
#  0-.25-.25Z"></path><path,
#  1-.75-.75Zm-4 0a.75.75,
#  <div,
#  fg,
#  -default,
#  a class="HeaderMenu-dropdown-link,
#  lh-condensed d,
#  secondary d-flex flex-items-center,
#  Copilot&quot;,&quot;label&quot;:&quot;ref_cta,
#  Copilot;&quot,
#  href="/features/copilot,
#  <svg aria-hidden="true" height="24" viewBox="0,
#  " version="1.1" width="24" data-view-component="true" class="octicon octicon-copilot color,
#  1-.052-1.086c0-1.331.282-2.499 1.132-3.368.397-.406.89-.717 1.474-.952,
#  1-.085-.104L4 11.741v6.585c1.435.779,
#  2.292-.337 2.657-.751.384-.435.558-1.15.558-2.361 0-1.14-.243-1.847-.705-2.319-.477-.488-1.319-.862-2.824-1.025-1.487-.161-2.192.138-2.533.529-.269.307-.437.808-.438 1.578v.021c0 .265.021.562.063.893Zm-1.626,
#  0c.042-.331.063-.628.063-.894v-.02c-.001-.77-.169,
#  1.902-.394 2.344-.938.475-.584.742-1.44.878-2.497Z"></path><path d="M14.5,
#  <div,
#  fg-default,
#  better code,
#  AI,
#  a class="HeaderMenu-dropdown-link,
#  -block no-underline position-relative py-2 Link,
#  secondary d-flex flex-items-center,
#  Code,
#  " href="/features/code-review">
#        <svg aria-hidden="true" height="24" viewBox="0,
#  24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-code-review color-fg-subtle mr-3">
#      <path d="M10.3 6.74a.75.75 0 0 1-.04 1.06l-2.908,
#  1 1-1.02-1.1l2.908-2.7-2.908-2.7Z"></path><path d="M1.5,
#  1.75.784,
#  1-1.75-1.75ZM3.25 4a.25.25,
#  1 .75.75v3.19l3.72,
#  1 .53-.22h10a.25.25,
#  <div,
#  div,
#  fg,
#  lh-condensed d,
#  secondary d-flex flex-items-center,
#  Issues&quot;,&quot;label&quot;:&quot;ref_cta,
#  Issues;&quot,
#  " href="/features/issues,
#  <svg aria-hidden="true" height="24" viewBox="0,
#  1c6.075,
#  fg-default,
#  a class="HeaderMenu-dropdown-link,
#  lh-condensed d,
#  secondary d-flex flex-items-center" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  Discussions&quot;,&quot;label&quot;:&quot;ref_cta,
#  Discussions;&quot,
#  " href="/features/discussions,
#  <svg aria-hidden="true" height="24" viewBox="0,
#  24 24" version="1.1" width="24" data-view-component="true" class="octicon octicon-comment-discussion color-fg-subtle mr-3">
#      <path,
#  1 1.75 1ZM1.5 2.75v9.5c0,
#  1 .75.75v2.19l2.72,
#  .25-.25v-9.5a.25.25,
#  0-.25-.25H1.75a.25.25,
#  0-.25.25Z"></path><path d="M22.5 8.75a.25.25,
#  fg-default,
#  code,
#  >
#            <div class="px-lg-4,
#  fg-default,
#  a class="HeaderMenu-dropdown-link,
#  position-relative py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  All features&quot;,&quot;label&quot;:&quot;ref_cta,
#  All features;&quot,
#  All features,
#  position-relative py-2 Link--secondary" target="_blank" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  Documentation&quot;,&quot;label&quot;:&quot;ref_cta,
#  Documentation;&quot,
#  height="16,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#      <path,
#  .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75,
#  1 12.25 14h-8.5A1.75,
#  1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
#  </svg>
#  </a></li>
#
#                  <li>
#    <a class="HeaderMenu-dropdown-link lh-condensed d,
#  position-relative py-2 Link--secondary" target="_blank" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  GitHub,
#  height="16,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#      <path,
#  .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75,
#  1 12.25 14h-8.5A1.75,
#  1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
#  </svg>
#  </a></li>
#
#                  <li>
#    <a class="HeaderMenu-dropdown-link lh-condensed d,
#  position-relative py-2 Link--secondary" target="_blank" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  Blog&quot;,&quot;label&quot;:&quot;ref_cta,
#  height="16,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#      <path,
#  .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75,
#  1 12.25 14h-8.5A1.75,
#  <li class="HeaderMenu-item,
#  <button type="button" class="HeaderMenu-link,
#  border-0,
#  lg,
#  px,
#  no-wrap,
#  <svg opacity="0.5,
#  " height="16,
#  5.22a.749.749,
#  lg,
#  lg,
#  -default,
#  heading">For</span,
#  -block,
#  Enterprise&quot;,&quot;label&quot;:&quot;ref_cta,
#  Enterprise;&quot,
#  lh-condensed d,
#  py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  Teams&quot;,&quot;label&quot;:&quot;ref_cta,
#  Teams;&quot,
#  " href="/team">
#        Teams,
#  lh-condensed d,
#  py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  Startups&quot;,&quot;label&quot;:&quot;ref_cta,
#  Startups;&quot,
#  }" href="/enterprise/startups">
#        Startups,
#  lh-condensed d,
#  no-underline position-relative py-2,
#  Education&quot;,&quot;label&quot;:&quot;ref_cta,
#  Education;&quot,
#  }" href="https://education.github.com">
#        Education
#
#      <svg aria-hidden="true" height="16" viewBox="0,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#      <path,
#  .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75,
#  1 12.25 14h-8.5A1.75,
#  mb-3,
#  >
#                <span,
#  -default,
#  solution,
#  no-underline position-relative py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  CI/CD,
#  amp;amp,
#  Automation&quot;,&quot;label&quot;:&quot;ref_cta:CI/CD,
#  amp;amp,
#  Automation;&quot,
#  }" href="/solutions/ci-cd/">
#        CI/CD,
#  amp,
#  Automation,
#  a class="HeaderMenu-dropdown-link,
#  no-underline position-relative py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  DevOps&quot;,&quot;label&quot;:&quot;ref_cta,
#  DevOps;&quot,
#  href="/solutions,
#  lh-condensed d,
#  DevSecOps&quot;,&quot;label&quot;:&quot;ref_cta,
#  }" href="https://resources.github.com/devops/fundamentals/devsecops/">
#        DevSecOps,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#      <path,
#  .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75,
#  1 12.25 14h-8.5A1.75,
#  -default,
#  py-2 Link--secondary" target="_blank" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  Learning,
#  Learning Pathways;&quot,
#  pathways/,
#  ">
#        Learning Pathways,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#      <path,
#  .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75,
#  1 12.25 14h-8.5A1.75,
#  1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
#  </svg>
#  </a></li>
#
#                  <li>
#    <a class="HeaderMenu-dropdown-link lh-condensed d,
#  position-relative py-2 Link--secondary" target="_blank" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  White papers,
#  Ebooks,
#  Webinars&quot;,&quot;label&quot;:&quot;ref_cta,
#  White papers,
#  Ebooks,
#  Webinars;&quot,
#  " href="https://resources.github.com/">
#        White papers,
#  Ebooks,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#      <path,
#  .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75,
#  1 12.25 14h-8.5A1.75,
#  1-1.042-.018.751.751 0 0 1-.018-1.042l3.75-3.75-1.543-1.543A.25.25 0 0 1 10.604 1Z"></path>
#  </svg>
#  </a></li>
#
#                  <li>
#    <a class="HeaderMenu-dropdown-link lh-condensed d,
#  position-relative py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  Customer Stories&quot;,&quot;label&quot;:&quot;ref_cta,
#  a class="HeaderMenu-dropdown-link,
#  py-2 Link--secondary" target="_blank" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  Partners&quot;,&quot;label&quot;:&quot;ref_cta,
#  Partners,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-link-external HeaderMenu-external-icon color-fg-subtle">
#      <path,
#  .25-.25v-3.5a.75.75 0 0 1 1.5 0v3.5A1.75,
#  1 12.25 14h-8.5A1.75,
#  <li class="HeaderMenu-item,
#  <button type="button" class="HeaderMenu-link,
#  border-0,
#  lg,
#  px,
#  no-wrap,
#  js-details-target,
#  <svg opacity="0.5,
#  " height="16,
#  5.22a.749.749,
#  lg,
#  lg,
#  none,
#  secondary d-flex flex-items-center" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  GitHub,
#  GitHub Sponsors;&quot,
#  href="/sponsors,
#  fg-default,
#  </div>
#            <div class="border-bottom,
#  mb-3,
#  none,
#  secondary d-flex flex-items-center" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  The ReadME Project&quot;,&quot;label&quot;:&quot;ref_cta,
#  The ReadME Project;&quot,
#  >
#
#        <div>
#          <div class="color-fg-default h4">The,
#  fg-default,
#  id="open-source-repositories,
#  heading">Repositories</span,
#  -block,
#  Topics&quot;,&quot;label&quot;:&quot;ref_cta,
#  Topics;&quot,
#  position-relative py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  Trending&quot;,&quot;label&quot;:&quot;ref_cta,
#  Trending;&quot,
#  lh-condensed d,
#  py-2 Link--secondary" data-analytics-event="{&quot;category&quot;:&quot;Header,
#  Collections&quot;,&quot;label&quot;:&quot;ref_cta,
#  Collections;&quot,
#  position-relative flex-wrap flex-justify-between flex-items-center,
#  d,
#  lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item,
#  a class="HeaderMenu-link no-underline,
#  px-lg-2 py-3 py-lg-2 d,
#  -block,
#  lg-inline-block,
#  out)&quot;,&quot;action&quot;:&quot;click,
#  Pricing&quot;,&quot;label&quot;:&quot;ref_cta,
#  Pricing;&quot,
#  <div class="d-lg-flex flex-items-center,
#  -lg,
#  "">
#
#
#
#  <qbsearch-input class="search-input" data-scope="repo,
#  suggestions,
#  Z5SYMHjMACpljc5D,
#  DiIh4x7HW6YpC3T9fstpUQ%3D%3D&quot,
#  dialog,
#  relative,
#  d-flex flex-row flex-items-center,
#  "
#      data-action="click,
#  none,
#  "
#          data-action="click,
#  qbsearch,
#  class="mr-2,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-search">
#      <path d="M10.68,
#  </div>
#          <span class="flex-1" data-target="qbsearch-input.inputButtonText">Search,
#  3 1.3 3 3v13c0 1.7-1.3 3-3 3h-12c-1.7 0-3-1.3-3-3v-13c0-1.7 1.3-3 3-3z"></path><path fill="#979A9C,
#  d="M11.8 6L8 15.1h-.9L10.8 6h1z"></path></svg>
#
#            </div>
#        </button>
#
#      <input type="hidden" name="type" class="js-site-search-type-field,
#  <div class="Overlay,
#  data-modal-dialog-overlay>
#    <modal-dialog data-action="close,
#  qbsearch-input#handleClose cancel,
#  labelledby="search,
#  id="search-suggestions-dialog-header" class="sr-only">Search code,
#  repositories,
#  users,
#  issues,
#  requests,
#  </h1>
#      <div class="Overlay-body Overlay-body,
#  ">
#
#            <div data-view-component="true,
#  >        <div,
#  class="search-suggestions,
#  fg-default,
#  bg,
#  overflow-hidden d-flex flex-column query-builder-container"
#            style="border-radius: 12px,
#  action="" accept-charset="UTF-8" method="get">
#    <query-builder data-target="qbsearch-input.queryBuilder" id="query-builder-query-builder-test" data-filter-key=,
#  data-view-component="true" class="QueryBuilder search-query-builder,
#  >
#      <div class="FormControl FormControl,
#  fullWidth,
#  <label,
#  -test,
#  builder,
#  /label>
#        <div
#          class="QueryBuilder-StyledInput width-fit "
#          data-target="query-builder.styledInput,
#  <div data-target="query-builder.styledInputContainer,
#  class="QueryBuilder-InputWrapper,
#  " class="QueryBuilder-Sizer" data-target="query-builder.sizer"></div>
#              <input id="query-builder-test" name="query-builder-test,
#  query,
#  query-builder#inputKeydown,
#  query-builder#inputFocus
#          " data-view-component="true" class="FormControl-input QueryBuilder-Input FormControl-medium,
#  </div>
#          </div>
#            <span,
#  builder.clearButton,
#  query-builder#clear
#                  focus,
#  query-builder#clearButtonFocus
#                  blur,
#  Button,
#  " height="16,
#  x,
#  13.657ZM6.03 4.97a.751.751,
#  0-.018,
#  8 4.97 9.97a.749.749,
#  0-.215-.734L9.06 8l1.97,
#  0-.326,
#  0-.734.215L8 6.94Z"></path>
#  </svg>
#  </button>
#
#        </div>
#        <template id="search-icon">
#    <svg aria-hidden="true" height="16" viewBox="0,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-search">
#      <path d="M10.68,
#  id="code-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-code,
#  path,
#  8l-3.72,
#  <template id="file-code-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-file-code,
#  <path,
#  1-1.5 0Zm1.72 4.97a.75.75 0 0 1 1.06 0l2 2a.75.75,
#  1-1.275-.326.749.749 0 0 1 .215-.734l1.47,
#  1-.018,
#  1-1.042.018l-2-2a.75.75,
#  <template id="history-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-history,
#  1.358A.25.25,
#  3.896 6H.25A.25.25,
#  1-.557 1.392l-2.5-1A.751.751 0 0 1 7 8.25v-3.5A.75.75 0 0 1 7.75 4Z"></path>
#  </svg>
#  </template>
#
#  <template id="repo-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-repo">
#      <path d="M2,
#  1 4.5 0h8.75a.75.75,
#  12.25a.25.25,
#  15.7a.25.25,
#  >
#  </template>
#
#  <template,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-bookmark">
#      <path,
#  1.75.784,
#  1-1.227.579L8 11.722l-3.773,
#  3.107A.751.751 0 0 1 3 14.25Zm1.75-.25a.25.25,
#  </template>
#
#  <template id="plus-circle-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-plus-circle,
#  path,
#  <template id="circle-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-dot-fill,
#  <template id="trash-icon,
#  " version="1.1" width="16" data-view-component="true" class="octicon octicon-trash">
#      <path d="M11,
#  6.6a.25.25,
#  1.748 0 0 1 10.595 15h-5.19a1.75,
#  1.75V3h3V1.75a.25.25,
#  </template>
#
#  <template,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-people,
#  <path,
#  1-1.482-.236A5.507 5.507 0 0 1 3.102 8.05 3.493 3.493 0 0 1 2 5.5ZM11 4a3.001,
#  0h12.5C15.216,
#  0-.25-.25H1.75a.25.25,
#  1-1.5 0ZM8 3a.75.75,
#  1 .75.75v3.5a.75.75,
#  1-1.5 0v-3.5A.75.75 0 0 1 8 3Z"></path>
#  </svg>
#  </template>
#
#  <template id="pencil-icon">
#    <svg aria-hidden="true" height="16" viewBox="0,
#  " version="1.1" width="16" data-view-component="true" class="octicon octicon-pencil,
#  >
#      <path,
#  1-.927-.928l.929-3.25c.081-.286.235-.547.445-.758l8.61-8.61Zm.176,
#  0-.354 0L10.811 3.75l1.439 1.44 1.263-1.263a.25.25 0 0 0 0-.354Z"></path,
#  </template>
#
#  <template,
#  15.035c-4.562,
#  1.206-.134,
#  1.23.137,
#  0-.765-.123-1.242-.37-1.554-.233-.296-.693-.587-1.713-.7Z"></path><path d="M6.25,
#  1 .75-.75Zm4.25.75v1.501a.75.75,
#  <template id="workflow-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-workflow,
#  7 .784 7 1.75v3.5A1.75,
#  1.75.784 1.75 1.75v3.5A1.75,
#  .25-.25v-3.5a.25.25,
#  0-.25-.25Zm9 9a.25.25,
#  .25-.25v-3.5a.25.25,
#  <template id="book-icon,
#  1h4.253c1.227,
#  <template,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-code-review">
#      <path,
#  1.784.784 1 1.75 1ZM1.5 2.75v8.5c0,
#  0 1 .75.75v2.19l2.72,
#  .25-.25v-8.5a.25.25,
#  0-.25-.25H1.75a.25.25,
#  1-.018,
#  -2a.75.75,
#  1 1.06 0Zm2.44,
#  2a.75.75,
#  <template id="codespaces-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-codespaces,
#  1.75.784,
#  .25-.25v-5a.25.25,
#  0-.25-.25Zm-2 9.5a.25.25,
#  .25-.25v-3a.25.25,
#  0-.25-.25Z"></path><path d="M7 12.75a.75.75,
#  1-.75-.75Zm-4 0a.75.75,
#  1-.75-.75Z"></path>
#  </svg>
#  </template>
#
#  <template,
#  id="comment-icon">
#    <svg aria-hidden="true" height="16" viewBox="0,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-comment">
#      <path,
#  d="M1 2.75C1,
#  1.75.784,
#  0 1 .75.75v2.19l2.72,
#  .25-.25v-7.5a.25.25,
#  template,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-comment-discussion">
#      <path,
#  1.75.784,
#  .138.112.25.25.25h1a.75.75,
#  0 1 .75.75v2.19l2.72,
#  .25-.25v-5.5a.25.25,
#  0-.25-.25h-8.5a.25.25 0 0 0-.25.25Zm13 2a.25.25,
#  0-.25-.25h-.5a.75.75,
#  1.75.784,
#  id="organization-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-organization,
#  <path,
#  .25-.25V8.285a.25.25,
#  1-.75-.75V14h-1v1.25a.75.75,
#  0-.25.25ZM3.75,
#  6h.5a.75.75,
#  1 0-1.5ZM3 9.75A.75.75,
#  9h.5a.75.75,
#  9.75ZM7.75 9h.5a.75.75,
#  <template id="rocket-icon,
#  >
#      <path,
#  1-1.11-.418l-.954-3.102a1.214 1.214 0 0 1-.145-.125L3.754 9.816a1.218,
#  1.74-1.26 2.499-2.02l.459-.458a7.25,
#  1-.064-.201c.103-.671.416,
#  <template id="shield-check-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-shield-check">
#      <path d="m8.533.133,
#  0-.174.237V7c0 1.36.275,
#  0c2.245-.957,
#  2.103 4.366-3.297C13.225,
#  0-.153,
#  1 1.042.018.751.751 0 0 1 .018 1.042Z"></path>
#  </svg>
#  </template>
#
#  <template id="heart-icon">
#    <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-heart">
#      <path,
#  14.25.345.666a.75.75,
#  1-3.434-2.414C2.045 10.731 0 8.35 0 5.5 0 2.836 2.086 1 4.25 1 5.797 1 7.153 1.802 8 3.02 8.847 1.802 10.203 1 11.75 1 13.914 1 16 2.836 16 5.5c0 2.85-2.045 5.231-3.885 6.818a22.066 22.066 0 0 1-3.744 2.584l-.018.01-.006.003h-.002ZM4.25,
#  >
#  </template>
#
#  <template,
#  1.75.784 1.75 1.75v4c0 .372-.116.717-.314,
#  1a1.739,
#  1-.314,
#  0-.25-.25H1.75a.25.25,
#  0-.25.25Zm.25 5.75a.25.25,
#  0-.25-.25ZM7,
#  1 0-1.5ZM3 4.75A.75.75,
#  1 0-1.5Z"></path>
#  </svg>
#  </template>
#
#  <template id="globe-icon">
#    <svg aria-hidden="true" height="16" viewBox="0,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-globe,
#  path,
#  10.22 8.75Zm4.44,
#  0-.857,
#  2.074-.866,
#  >
#  </template>
#
#  <template,
#  id="issue-opened-icon,
#  " height="16" viewBox="0,
#  d="M8,
#  3Z"></path><path,
#  d="M8,
#  <template id="device-mobile-icon,
#  width="16" data-view-component="true" class="octicon octicon-device-mobile,
#  0h8.5C13.216,
#  1.75v12.5c0 .138.112.25.25.25h8.5a.25.25,
#  >
#  </template>
#
#  <template id="package-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-package,
#  <path d="m8.878.392,
#  1-.872 1.514l-5.25 3.045a1.75 1.75 0 0 1-1.756 0l-5.25-3.045A1.75 1.75 0 0 1 1 11.049V4.951c0-.624.332-1.201.872-1.514L7.122.392a1.75 1.75 0 0 1 1.756 0ZM7.875,
#  <template id="credit-card-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-credit-card">
#      <path,
#  1.5h1.5a.75.75 0 0 0 0-1.5h-1.5Z"></path><path d="M0,
#  1.75.784,
#  1 14.25 14H1.75A1.75,
#  6.5h-13v5.75c0,
#  .25-.25Zm0,
#  0-.25-.25H1.75a.25.25,
#  </template>
#
#  <template id="play-icon">
#    <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-play,
#  d="M8,
#  4.264 2.559a.25.25,
#  <template id="gift-icon,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-gift,
#  0c.983,
#  10.266 0 11.25 0a2.75,
#  1.75.784,
#  1 13.25 16H2.75A1.75,
#  1.25ZM7.25,
#  0v5h4.5a.25.25,
#  .25-.25v-2a.25.25,
#  0-.25-.25Zm-7 0a.25.25,
#  >
#  </template>
#
#  <template,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-code-square">
#      <path,
#  1.75 0 0 1 0 14.25Zm1.75-.25a.25.25,
#  1 0-1.06ZM6.78 6.53 5.31 8l1.47 1.47a.749.749,
#  <template id="device-desktop-icon,
#  <path d="M14.25,
#  1c.966,
#  .25-.25v-7.5a.25.25,
#  1-.765 2.5h3.566a5.72,
#  "
#                    data,
#  query,
#  query-builder#resultsMousedown,
#  false
#                    id="query-builder-test-results,
#  inlineValidation,
#  " href="https://docs.github.com/search-github/github-code-search/understanding-github-code-search-syntax" data-view-component="true" class="Link color-fg-accent text-normal ml-2">
#                Search syntax tips,
#  </div>
#  </modal-dialog></div>
#    </div>
#    <div data-action="click,
#  qbsearch-input#handleDialogClose" id="feedback-dialog" aria-modal="true" aria-labelledby="feedback-dialog-title" aria-describedby="feedback-dialog-description" data-view-component="true" class="Overlay,
#  Overlay-whenNarrow Overlay--size-medium Overlay,
#  motion,
#  -headerContentWrap,
#  class="Overlay,
#  ">
#        <h1,
#  feedback,
#  class="Overlay,
#  >
#        <button data-close-dialog-id="feedback-dialog" aria,
#  " type="button" data-view-component="true" class="close-button Overlay-closeButton"><svg aria-hidden="true" height="16" viewBox="0,
#  ">
#      <path,
#  1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z"></path>
#  </svg></button>
#      </div>
#    </div>
#  </div>
#        <scrollable-region data-labelled-by="feedback-dialog-title">
#          <div data-view-component="true" class="Overlay-body,
#  --><!--,
#  turbo="false,
#  We,
#  every piece,
#  feedback,
#  your input,
#  <textarea,
#  " class="form-control width-full mb-2" style="height: 120px,
#  id="feedback"></textarea>
#            <input name="include_email" id="include_email" aria-label="Include my email address,
#  I,
#  " class="form-control mr-2" type="checkbox,
#  <label for="include_email" style="font-weight,
#  my email address,
#  I,
#  contacted</label,
#  <div data-view-component="true" class="Overlay-footer Overlay-footer,
#  </button>
#            <button form="code-search-feedback-form" data-action="click,
#  qbsearch-input#submitFeedback" type="submit" data-view-component="true" class="btn-primary btn,
#  feedback,
#  labelledby="custom,
#  Overlay-whenNarrow Overlay--size-medium Overlay,
#  motion,
#  ">
#      <div data-view-component="true" class="Overlay-header Overlay-header,
#  -headerContentWrap,
#  ">
#        <h1,
#  class="Overlay-title " id="custom-scopes-dialog-title">
#          Saved searches,
#  </h1>
#          <h2,
#  class="Overlay,
#  searches,
#  your results,
#  class="Overlay,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon,
#  ">
#      <path,
#  1-1.042-.018.751.751 0 0 1-.018-1.042L6.94 8 3.72 4.78a.75.75 0 0 1 0-1.06Z"></path>
#  </svg></button>
#      </div>
#    </div>
#  </div>
#        <scrollable-region data-labelled-by="custom-scopes-dialog-title">
#          <div data-view-component="true" class="Overlay-body,
#  --><!--,
#  turbo="false,
#  target="custom-scopes.customScopesModalDialogFlash"></div,
#  >
#              <label,
#  maxlength="50,
#  >
#              </auto-check,
#  a,
#  mona,
#  /b,
#  python,
#  maxlength="500,
#  </div>
#
#            <p,
#  all available qualifiers,
#  our <a class="Link,
#  inTextBlock" href="https://docs.github.com/search-github/github-code-search/understanding-github-code-search-syntax">documentation</a,
#  >
#
#          <div data-target="custom-scopes.manageCustomScopesForm,
#  -scopes.list"></div,
#  <div data-view-component="true" class="Overlay-footer Overlay-footer,
#  >          <button data-action="click,
#  </button>
#            <button form="custom-scopes-dialog-form" data-action="click,
#  saved search,
#  >
#  </dialog></dialog-helper,
#  </custom-scopes,
#  suggestions,
#  sign,
#  exampleData,
#  prideAndPrejudiceChapters.txt&quot;,&quot;user_id&quot;:null,
#  Sign,
#  text:sign-in">
#                Sign,
#  =,
#  header+logged+out&amp;ref_page=%2F%3Cuser-name%3E%2F%3Crepo-name%3E%2Fblob%2Fshow&amp;source,
#  none,
#  lg-inline,
#  py-1"
#                data-hydro-click="{&quot;event_type&quot;:&quot;authentication.click&quot;,&quot;payload&quot;:{&quot;location_in_page&quot;:&quot;site header,
#  exampleData,
#  prideAndPrejudiceChapters.txt&quot;,&quot;user_id&quot;:null,
#  }" data-hydro-click-hmac="255885cf5985c80f043c3f42071efd6e8d8d7ac6fa1f3db82d43990c604a6eb7"
#                data-analytics,
#  name&gt;/&lt;repo-name&gt;/blob,
#  Sign up;ref_loc,
#  header,
#  out&quot,
#  }"
#              >
#                Sign,
#  " data-view-component="true" class="js-stale-session-flash stale-session-flash flash flash-warn flash-full mb-3">
#
#          <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-alert,
#  0-.44,
#  span,
#  You,
#  another tab,
#  window,
#  <a class="Link,
#  inTextBlock,
#  your session.</span>
#          <span,
#  You,
#  another tab,
#  window,
#  <a class="Link,
#  inTextBlock,
#  your session.</span>
#          <span,
#  You,
#  accounts,
#  another tab,
#  window,
#  <a class="Link,
#  inTextBlock,
#  id="icon-button-c2a17553-19f8-4b9e-8d9d-9fcab2590915,
#  399d-4d4b-9b0b-e6930c163c10,
#  Button,
#  height="16,
#  >
#  </button><tool-tip id="tooltip-84a43820-399d-4d4b-9b0b-e6930c163c10" for="icon-button-c2a17553-19f8-4b9e-8d9d-9fcab2590915" popover="manual" data-direction="s" data-type="label" data-view-component="true" class="sr-only position-absolute">Dismiss,
#  content,
#  focus"></div,
#  <template class="js-flash-template,
#  >
#
#  <div class="flash,
#  {{ className }}">
#    <div >
#      <button autofocus,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon,
#  ">
#      <path,
#  <div,
#  { message,
#  beta/shelf"></include-fragment,
#  data-discussion-hovercards-enabled
#      data-issue-and-pr-hovercards,
#  -pjax,
#  full-screen,
#  style="background-color,
#  var(--page-header-bgColor,
#  bg,
#  <div class="d-flex flex-wrap flex-justify-end,
#  md-4,
#  ">
#
#    <div class=" d-flex flex-wrap flex-items-center wb-break-word f3 text-normal">
#        <svg aria-hidden="true" height="16" viewBox="0,
#  ">
#      <path d="M2,
#  1 4.5 0h8.75a.75.75,
#  12.25a.25.25,
#  15.7a.25.25,
#  class="author,
#  turbo,
#  </strong>
#
#      <span></span><span class="Label Label,
#  secondary v-align-middle mr-1">Public</span,
#  </div>
#
#          <div id="repository-details-container" data-turbo-replace,
#  ul,
#  class="pagehead,
#  -actions,
#  none,
#  2px,
#  a,
#  exampleData,
#  " aria-label="You,
#  notification settings,
#  data-view-component="true,
#  >    <svg aria-hidden="true" height="16" viewBox="0,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-bell,
#  ">
#      <path,
#  16ZM3 5a5 5 0 0 1 10 0v2.947c0 .05.015.098.042.139l1.703,
#  2.555A1.519 1.519 0 0 1 13.482 13H2.518a1.516 1.516 0 0 1-1.263-2.36l1.703-2.554A.255.255 0 0 0 3 7.947Zm5-3.5A3.5,
#  0-.003.01l.001.006c0,
#  Notifications,
#  a icon="repo-forked" id="fork-button" href="/login?return_to=%2Fdustywhite7%2FpythonMikkeli" rel="nofollow" data-hydro-click="{&quot;event_type&quot;:&quot;authentication.click&quot;,&quot;payload&quot;:{&quot;location_in_page&quot;:&quot;repo details,
#  dustywhite7,
#  pythonMikkeli/blob/master,
#  exampleData,
#  prideAndPrejudiceChapters.txt&quot;,&quot;user_id&quot;:null,
#  click,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon,
#  >
#      <path,
#  .75-.75v-.878a2.25 2.25 0 1 1 1.5 0v.878a2.25,
#  2.25 0 0 1-2.25 2.25h-1.5v2.128a2.251,
#  1 1 1.5 0ZM5,
#  >
#
#    <li>
#          <div data-view-component="true,
#  a,
#  exampleData,
#  -hmac="8b826e4d74f8a7801c49fdc4ac3e2da200ebb501ff2beb5c211a2ba3aca8c467,
#  a repository" data-view-component="true,
#  tooltipped-s btn-sm btn BtnGroup-item,
#  >    <svg aria-hidden="true" height="16" viewBox="0,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-star v-align-text-bottom d-inline-block,
#  path,
#  0 1 .673.418l1.882 3.815 4.21.612a.75.75,
#  1.279l-3.046 2.97.719,
#  1-1.088.791L8 12.347l-3.766,
#  1-1.088-.79l.72,
#  1-.564-.41L8 2.694Z"></path>
#  </svg><span data-view-component="true" class="d-inline">
#            Star,
#  span id="repo-stars-counter,
#  -,
#  " aria-label="4 users,
#  this repository" data-singular-suffix="user,
#  this repository" data-plural-suffix="users,
#  this repository" data-turbo-replace="true" title="4" data-view-component="true" class="Counter,
#  js-social-count">4</span,
#  button aria-label="You,
#  this repository,
#  a list,
#  type="button,
#  " disabled="disabled" data-view-component="true" class="btn-sm btn BtnGroup-item px-2">    <svg aria-hidden="true" height="16" viewBox="0 0 16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-triangle-down">
#      <path,
#  d="m4.427,
#  0l3.396-3.396A.25.25,
#  repo-pjax-container,
#  nav,
#  lg-5,
#  <ul data-view-component="true" class="UnderlineNav-body list-style,
#  pythonMikkeli,
#  content,
#  turbo,
#  navbar&quot;,&quot;action&quot;:&quot;Click,
#  tab&quot;,&quot;label&quot;:&quot;Code&quot;,&quot;target&quot;:&quot;UNDERLINE_NAV.TAB&quot,
#  no-wrap,
#  underlinenav-item,
#  sm,
#  inline,
#  8l-3.72,
#  1 0-1.06Z"></path>
#  </svg>
#          <span,
#  tab,
#  turbo,
#  no-wrap,
#  underlinenav-item,
#  inline,
#  d="M8,
#  3Z"></path><path,
#  d="M8,
#  data-content="Issues">Issues</span>
#            <span,
#  tab,
#  item="i2pull,
#  turbo,
#  underlinenav-item,
#  height="16,
#  16 16" version="1.1" width="16" data-view-component="true" class="octicon octicon-git-pull-request,
#  inline,
#  ">
#      <path d="M1.5,
#  >
#          <span data-content="Pull requests">Pull requests</span,
#  tab,
#  turbo,
#  " data-view-component="true" class="UnderlineNav-item,
#  UnderlineNav-octicon d,
#  inline,
#  ">
#      <path,
#  4.264 2.559a.25.25,
#  .428l-4.264,
#  tab,
#  "" data-turbo-replace=,
#  data-tab-item="i4projects-tab,
#  data-pjax="#repo-content-pjax-container,
#  underlinenav-item,
#  sm,
#  14.25ZM6.5 6.5v8h7.75a.25.25,
#  0-.25-.25H6.5V5Zm-13,
#  5V1.5H1.75a.25.25,
#  tab,
#  ...]
